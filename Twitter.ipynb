# %%
def funcion (a):
    print("Hola", a)
    return a+" asssd"

# %%
import sys
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-8_2.11:2.0.2 pyspark-shell'

from pyspark import SparkContext
from pyspark.streaming import StreamingContext

from pyspark.streaming.kafka import KafkaUtils

sc = SparkContext(appName="Twitter_Streaming")

ssc = StreamingContext(sc, 1)

# %%
topics = ['este']

kafkaParams = {'bootstrap.servers': 'broker:29092', 
               'group.id' : 'test'}

stream = KafkaUtils.createDirectStream(ssc, topics, kafkaParams)

stream.map(lambda record : (record[0], record[1])).pprint()

#stream.map(lambda record: funcion(record[1])).pprint()

ssc.start()
ssc.awaitTermination()
# Out:
# -------------------------------------------
# Time: 2021-01-23 17:48:34
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-23 17:48:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-23 17:48:36
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-23 17:48:37
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-23 17:48:38
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-23 17:48:39
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-23 17:48:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-23 17:48:41
# -------------------------------------------
#
# ...

# %%
from pyspark import sql
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

spark = SparkSession \
    .builder \
    .appName("Twitter_Streaming") \
    .getOrCreate()

# %%
""""
counts = enchufe.flatMap(lambda line: line.split(" "))\
                  .map(lambda word: (word, 1))\
                  .reduceByKey(lambda a, b: a+b)
counts.pprint()
""""

# %%
pip install tweepy

# %%
import tweepy
from tweepy import OAuthHandler

# %%
consumer_key = "ZHwb6JawdsgTUZreb4yZeb2tX"
consumer_secret = "2UoU6lEpNeTPM847paK6X6z6BVoUENhPq87rIIWcOycnNhGtpd"
access_token = "1346037018132930560-G3afFHkhsPiYlo1yFO3X4mTmdJhTOY"
access_token_secret = "jLjtkTK9VQVitacVhLj8QtSdb0mkOto4J9PDDSWR9x9Q0"

# %%
# Configuración de acceso con las credenciales
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
 
# Listos para hacer la conexión con el API
api = tweepy.API(auth)

# %%
# Publicar nuevo tweet
texto = 'Hola, amiguitos'
api.update_status(texto)

# %%
# Agregar una respuesta a un tweet
api.update_status(status = 'Hola holita', in_reply_to_status_id = 1352652859863662599, auto_populate_reply_metadata = True)

# %%
# Agregar una respuesta a un tweet 2.0
api.update_status("Va???", in_reply_to_status_id = 1352950617413705728)

# %%
# Retweetear un tweet
api.retweet(1352950617413705728)

# %%
imagen = open("Imagen.jpg", 'rb')
id_imagen = api.media_upload(file=img)
print(id_imagen)

api.update_status("Comentario", media_ids=[id_imagen.media_id_string])

# %%
f_imagen = "Imagen.jpg"
tweet = 'A ver si consigo twittear una imagen...'
api.update_with_media(f_imagen, status=tweet)
